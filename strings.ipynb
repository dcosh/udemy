# %%
x = 'Hello World'

# %%
x = x + ' it is beautifull outside'

# %%
x
# Out:
# 'Hello World it is beautifull outside'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
letter.upper()
# Out:
# 'Z'

# %%
x = 'Hello World'

# %%
x = 'Hi this is a string'

# %%
x.split('/n')
# Out:
# ['Hi this is a string']
